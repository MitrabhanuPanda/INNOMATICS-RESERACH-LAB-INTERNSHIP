# %%
import pandas as pd
import numpy as np

# %%
path=r"C:\Users\mitra\Desktop\INNOMATICS(MITRABHANU PANDA)\GEN AI (ADVANCE)\6. PROJECTS\5. CLONING SHAZAM\col_data\shazamdata.csv"

# %%
df = pd.read_csv(path)
df.shape
# Out:
# (24749, 4)

# %%
df.columns
# Out:
# Index(['num', 'name', 'content', 'file_content'], dtype='object')

# %%
df_new = df[['num', 'name', 'file_content']]
df_new
# Out:
#            num                                               name  \
# 0      9400085                 markova.comfort.gay.(2000).eng.1cd
# 1      9346856  echo.3.s01.e05.we.reject.your.influence.(2022)...
# 2      9255300             911.s06.e02.crash.learn.(2022).eng.1cd
# 3      9289002  guadalupe.the.miracle.and.the.message.(2015).e...
# 4      9352230  dae.wang.sejong.s01.e61.episode.1.61.(2008).en...
# ...        ...                                                ...
# 24744  9423098          the.xfiles.s07.e22.requiem.(2000).eng.1cd
# 24745  9309944  detective.conan.s01.e14.the.mysterious.shootin...
# 24746  9467766    snowfall.s06.e05.ebony.and.ivory.(2023).eng.1cd
# 24747  9340246     shark.tank.s14.e05.episode.14.5.(2022).eng.1cd
# 24748  9225683  american.horror.stories.s02.e07.necro.(2022).e...
#
#                                             file_content
# 0      ï»¿1\r\n00:00:06,000 --> 00:00:12,074\r\nWatch...
# 1      ï»¿1\r\n00:00:10,095 --> 00:00:11,513\r\n[dog ...
# ...

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer

# %%
lemmatizer = WordNetLemmatizer()

# %%
def preprocess(raw_text):
    # Remove HTML tags
    text = BeautifulSoup(raw_text, 'html.parser').get_text()
    
    # Removing special characters and digits
    special_char = re.sub("[^a-zA-Z]", " ", text)
    
    # change sentence to lower case
    lowered = special_char.lower()
    
    
    sentence = re.sub('\s+', ' ', lowered)

    tokens = sentence.split()
    
    # Lemmatization
    clean_tokens = [lemmatizer.lemmatize(word) for word in tokens]
    
    return pd.Series([" ".join(clean_tokens), len(clean_tokens)])

# %%
from tqdm import tqdm, tqdm_notebook
import re
from bs4 import BeautifulSoup

# %%
# Register `pandas.progress_apply` and `pandas.Series.map_apply` with `tqdm`

tqdm.pandas()

# %%
# Now you can use `progress_apply` instead of `apply`
# and `progress_map` instead of `map`

temp_df = df_new['file_content'].progress_apply(lambda x: preprocess(x))

temp_df.head()
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████| 24749/24749 [32:59<00:00, 12.50it/s]
#                                                    0     1
# 0  watch any video online with open subtitle free...  4930
# 1  dog barking lowing barking lowing barking cont...  3802
# 2  support u and become vip member to remove all ...  4123
# 3  choir singing api opensubtitles org is depreca...  4284
# 4  support u and become vip member to remove all ...  3336

# %%
temp_df.columns = ['clean_text_lemma', 'text_length_lemma']

temp_df.head()
# Out:
#                                     clean_text_lemma  text_length_lemma
# 0  watch any video online with open subtitle free...               4930
# 1  dog barking lowing barking lowing barking cont...               3802
# 2  support u and become vip member to remove all ...               4123
# 3  choir singing api opensubtitles org is depreca...               4284
# 4  support u and become vip member to remove all ...               3336

# %%
df_new = pd.concat([df_new, temp_df], axis=1)
df_new.head()
# Out:
#        num                                               name  \
# 0  9400085                 markova.comfort.gay.(2000).eng.1cd
# 1  9346856  echo.3.s01.e05.we.reject.your.influence.(2022)...
# 2  9255300             911.s06.e02.crash.learn.(2022).eng.1cd
# 3  9289002  guadalupe.the.miracle.and.the.message.(2015).e...
# 4  9352230  dae.wang.sejong.s01.e61.episode.1.61.(2008).en...
#
#                                         file_content  \
# 0  ï»¿1\r\n00:00:06,000 --> 00:00:12,074\r\nWatch...
# 1  ï»¿1\r\n00:00:10,095 --> 00:00:11,513\r\n[dog ...
# 2  ï»¿1\r\n00:00:06,000 --> 00:00:12,074\r\nSuppo...
# 3  1\r\n00:00:06,539 --> 00:00:09,542\r\n[choir s...
# 4  ï»¿1\r\n00:00:06,000 --> 00:00:12,074\r\nSuppo...
#
#                                     clean_text_lemma  text_length_lemma
# 0  watch any video online with open subtitle free...               4930
# 1  dog barking lowing barking lowing barking cont...               3802
# ...

# %%
df_10 = df_new.sample(frac=0.1)
df_10
# Out:
#            num                                               name  \
# 596    9333709  bleach.s14.e02.connected.hearts.the.left.fist....
# 7036   9279523  scorpion.s04.e22.a.lie.in.the.sand.(2018).eng.1cd
# 10362  9437204  diagnosis.murder.s03.e11.murder.murder.(1996)....
# 10229  9339575      mr.mayor.s02.e05.sister.cities.(2022).eng.1cd
# 19242  9282951  the.mentalist.s07.e03.orange.blossom.ice.cream...
# ...        ...                                                ...
# 6197   9388272  24.s08.e20.day.8.1100.a.m.1200.p.m.(2010).eng.1cd
# 2662   9246408  knight.rider.s01.e10.dont.stop.the.knight.(200...
# 7385   9427577                   letter.never.sent.(1960).eng.1cd
# 114    9247709  bob.hearts.abishola.s04.e01.touched.by.a.holy....
# 6878   9243936  ray.donovan.s04.e11.chinese.algebra.(2016).eng...
#
#                                             file_content  \
# 596    [Script Info]\r\nTitle: English\r\nOriginal Sc...
# ...

# %%
# df_10.to_csv(r"C:\Users\mitra\Desktop\INNOMATICS(MITRABHANU PANDA)\GEN AI (ADVANCE)\6. PROJECTS\5. CLONING SHAZAM\col_data\shazam10.csv", index=False, escapechar="\\")

# %%
df_10.sample(50)
# Out:
#            num                                               name  \
# 11430  9266903      castle.s05.e01.after.the.storm.(2012).eng.1cd
# 5067   9229467  power.book.iii.raising.kanan.s02.e04.pay.the.t...
# 21637  9185695    another.self.s01.e01.episode.1.1.(2022).eng.1cd
# 2356   9258203                    human.playground.(2022).eng.6cd
# 19556  9346033  heroes.s04.e13.chapter.thirteen.let.it.bleed.(...
# 13654  9191003                 their.first.mistake.(1932).eng.1cd
# 3565   9252941               ncis.s17.e18.schooled.(2020).eng.1cd
# 23005  9459043  the.playboy.murders.s01.e06.sugar.baby.(2023)....
# 5895   9370200  the.mindy.project.s01.e09.josh.and.mindys.chri...
# 15681  9337758  firefly.lane.s02.e01.wish.you.were.here.(2022)...
# 11351  9337788        hot.skull.s01.e04.high.fever.(2022).eng.1cd
# 16020  9196339                 tale.of.two.sisters.(1989).eng.1cd
# 2558   9418435      murder.in.big.horn.s01.e01.101.(2023).eng.1cd
# ...

# %%
df_20 = df_new.sample(frac=0.2)

# %%
# df_20.to_csv(r"C:\Users\mitra\Desktop\INNOMATICS(MITRABHANU PANDA)\GEN AI (ADVANCE)\6. PROJECTS\5. CLONING SHAZAM\col_data\shazam20.csv", index=False, escapechar="\\")

# %%
df_20
# Out:
#            num                                               name  \
# 2384   9243705             un.enfant.dans.la.foule.(1976).eng.1cd
# 22237  9454076  as.time.goes.by.s03.e07.the.miniseries.(1994)....
# 1235   9269306                   give.me.your.hand.(2008).eng.1cd
# 5579   9413856  hoax.the.kidnapping.of.sherri.papini.(2023).en...
# 19981  9337050                suzuka.s01.e08.kyori.(2005).eng.1cd
# ...        ...                                                ...
# 8121   9441553                             wendigo.(1995).eng.1cd
# 11024  9270218            fbi.s05.e03.prodigal.son.(2022).eng.1cd
# 14364  9313832  nature.s38.e01.octopus.making.contact.(2019).e...
# 9976   9396685  outlander.s02.e13.dragonfly.in.amber.(2016).en...
# 3745   9188327                 jonnys.golden.quest.(1993).eng.1cd
#
#                                             file_content  \
# 2384   ï»¿1\r\n00:00:20,108 --> 00:00:24,257\r\n<font...
# ...
